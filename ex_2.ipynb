# %% [markdown]
# <a href="https://colab.research.google.com/github/it20649708/Deep-Learing-Lab03-2023/blob/main/ex_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load the image using OpenCV

# %%
import cv2
import os

# Specify the relative path to your image
relative_path = 'sample_data/lenna.png'

# Construct an absolute path
#image_path = os.path.abspath(relative_path)

# Provide the file path to the image you want to load
image_path = '/content/drive/MyDrive/lenna.png'  # Change the path to your image


# Check if the image was loaded successfully
if im is not None:
    print("Image loaded successfully.")
    print("Image shape:", im.shape)  # Print the shape of the image (height, width, channels)

else:
    print("Failed to load the image. Please check the file path.")
# Out:
# Image loaded successfully.
# Image shape: (512, 512, 3)

# %%
im.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ### Convert the RGB image into a grayscale image

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im.shape
# Out:
# (512, 512)

# %% [markdown]
# ### Define vertical and horizontal filter kernels

# %%
v_kernel = np.array([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1]
])

# %%
h_kernel = np.array([
    [-1, -1, -1],
    [0, 0, 0],
    [1, 1, 1]
])

# %% [markdown]
# ### Do the filtering

# %%
v_image = cv2.filter2D(im, -1, v_kernel)
h_image = cv2.filter2D(im, -1, h_kernel)

# %% [markdown]
# ### Display results

# %%
plt.imshow(im, cmap='gray')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='gray')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='gray')
plt.title('Horizontal Image')
# Out:
# Text(0.5, 1.0, 'Horizontal Image')

# %%
v_image = cv2.filter2D(im, -2, v_kernel)
h_image = cv2.filter2D(im, -2, h_kernel)

# %%
plt.imshow(im, cmap='Blues')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='Blues')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='Blues')
plt.title('Horizontal Image')
# Out:
# Text(0.5, 1.0, 'Horizontal Image')

# %%
plt.imshow(im, cmap='Oranges')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='Oranges')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='Oranges')
plt.title('Horizontal Image')
# Out:
# Text(0.5, 1.0, 'Horizontal Image')

# %%
plt.imshow(im, cmap='YlOrRd')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='YlOrRd')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='YlOrRd')
plt.title('Horizontal Image')
# Out:
# Text(0.5, 1.0, 'Horizontal Image')

# %%
plt.imshow(im, cmap='copper')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='copper')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='YlOrRd')
plt.title('Horizontal Image')
# Out:
# Text(0.5, 1.0, 'Horizontal Image')
